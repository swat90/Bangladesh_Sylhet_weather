# %% [markdown]
# <a href="https://colab.research.google.com/github/swat90/Bangladesh_Sylhet_weather/blob/main/debt_pay_pulp_140524.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Debt Optimization

# %%
# !pip install pulp
# Out:
# Collecting pulp
#   Downloading PuLP-2.8.0-py3-none-any.whl (17.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 31.9 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.8.0

# %%
import pandas as pd
import numpy as np

# Define the number of students and debts per student
num_students = 10
debts_per_student = np.random.randint(2, 5, size=num_students)  # Each student has 2 to 4 debts

# Generate synthetic data for characteristics shared among students with the same ID
student_characteristics = pd.DataFrame({
    'Student ID': range(1, num_students + 1),
    'Fellowship Amount': np.random.randint(1000, 3000, size=num_students),
    'Daily Needs Funds': np.random.randint(800, 1500, size=num_students),
    'Part-time Job Income': np.random.randint(800, 2000, size=num_students),
    'Emergency Funds': np.random.randint(100, 500, size=num_students)
})

# Initialize empty lists to store data
student_ids = []
loan_ids = []
debts = []
principal_loan_amounts = []
balances = []
interest_rates = []
monthly_payments = []
total_available_funds = []
fellowship_amounts = []
daily_needs = []
part_time_incomes = []
emergency_funds = []

# Generate synthetic data for each student
for student_id in range(1, num_students + 1):
    num_debts = debts_per_student[student_id - 1]
    student_data = student_characteristics[student_characteristics['Student ID'] == student_id].iloc[0]
    fellowship_amount = student_data['Fellowship Amount']
    daily_needs_funds = student_data['Daily Needs Funds']
    part_time_job_income = student_data['Part-time Job Income']
    emergency_fund = student_data['Emergency Funds']
    for debt_id in range(1, num_debts + 1):
        student_ids.append(student_id)
        loan_ids.append(student_id)  # Assign the same loan ID for debts belonging to the same student
        debts.append(debt_id)
        principal_loan_amount = np.random.randint(8000, 15000)  # Random principal loan amount between 5000 and 10000
        principal_loan_amounts.append(principal_loan_amount)
        balance = np.random.randint(1000, principal_loan_amount)  # Random balance between 1000 and principal loan amount
        balances.append(balance)
        interest_rate = np.random.uniform(0.05, 0.2)  # Random interest rate between 5% and 20%
        interest_rates.append(interest_rate)
        monthly_payment = min(np.random.randint(50, 200), balance)  # Random monthly payment between 50 and 200, capped at balance
        monthly_payments.append(monthly_payment)
        total_funds = part_time_job_income + fellowship_amount + daily_needs_funds + emergency_fund
        total_available_funds.append(total_funds)
        fellowship_amounts.append(fellowship_amount)
        daily_needs.append(daily_needs_funds)
        part_time_incomes.append(part_time_job_income)
        emergency_funds.append(emergency_fund)

# Create DataFrame
data = pd.DataFrame({
    'Student ID': student_ids,
    'Loan ID': loan_ids,
    'Debt ID': debts,
    'Principal Loan Amount': principal_loan_amounts,
    'Balance': balances,
    'Interest Rate': interest_rates,
    'Monthly Payment': monthly_payments,
    'Total Available Funds': total_available_funds,
    'Fellowship Amount': fellowship_amounts,
    'Daily Needs Funds': daily_needs,
    'Part-time Job Income': part_time_incomes,
    'Emergency Funds': emergency_funds
})

# %%
data.head(10)
# Out:
#    Student ID  Loan ID  Debt ID  Principal Loan Amount  Balance  \
# 0           1        1        1                  11287     2550
# 1           1        1        2                  11358     1959
# 2           2        2        1                  13258    10913
# 3           2        2        2                   8489     2103
# 4           2        2        3                  10060     5740
# 5           3        3        1                  12772     1937
# 6           3        3        2                  11532     9229
# 7           4        4        1                  14297    10527
# 8           4        4        2                  12323     2425
# 9           4        4        3                  12874     6089
#
#    Interest Rate  Monthly Payment  Total Available Funds  Fellowship Amount  \
# 0       0.127529              117                   3207               1171
# 1       0.161902              128                   3207               1171
# 2       0.184564              182                   6305               2756
# 3       0.153454              150                   6305               2756
# 4       0.126064              179                   6305               2756
# 5       0.124043              177                   5423               2180
# 6       0.069475              158                   5423               2180
# 7       0.189860               96                   4425               2109
# 8       0.144719              146                   4425               2109
# 9       0.117156               97                   4425               2109
#
#    Daily Needs Funds  Part-time Job Income  Emergency Funds
# 0                963                   853              220
# 1                963                   853              220
# 2               1447                  1620              482
# 3               1447                  1620              482
# 4               1447                  1620              482
# 5               1128                  1893              222
# 6               1128                  1893              222
# 7               1050                   837              429
# 8               1050                   837              429
# 9               1050                   837              429

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student ID             30 non-null     int64
#  1   Loan ID                30 non-null     int64
#  2   Debt ID                30 non-null     int64
#  3   Principal Loan Amount  30 non-null     int64
#  4   Balance                30 non-null     int64
#  5   Interest Rate          30 non-null     float64
#  6   Monthly Payment        30 non-null     int64
#  7   Total Available Funds  30 non-null     int64
#  8   Fellowship Amount      30 non-null     int64
#  9   Daily Needs Funds      30 non-null     int64
#  10  Part-time Job Income   30 non-null     int64
#  11  Emergency Funds        30 non-null     int64
# dtypes: float64(1), int64(11)
# memory usage: 2.9 KB

# %%
import pandas as pd
import numpy as np

# Define the number of debts for one student
num_debts = np.random.randint(2, 5)  # One student has 2 to 4 debts

# Generate synthetic data for characteristics of one student
student_characteristics = {
    'Student ID': 1,
    'Fellowship Amount': 2000,
    'Daily Needs Funds': 800,
    'Part-time Job Income': 1000,
    'Emergency Funds': 300,
}

# Initialize empty lists to store data
debts = []
balances = []
interest_rates = []
minimum_monthly_payments = []
loan_tenures = []  # List to store loan tenure for each debt

# Generate synthetic data for the student's debts
for debt_id in range(1, num_debts + 1):
    debts.append(debt_id)
    balance = np.random.randint(12000, 20000)  # Random principal loan amount between 8000 and 15000
    balances.append(balance)
    interest_rate = np.random.uniform(0.05, 0.2)  # Random interest rate between 5% and 20%
    interest_rates.append(interest_rate)
    loan_tenure = np.random.randint(36, 60)  # Random loan tenure between 1 and 5 years (12 to 60 months)
    loan_tenures.append(loan_tenure)
    minimum_monthly_payment = balance / loan_tenure  # Calculate minimum monthly payment based on balance and tenure
    minimum_monthly_payments.append(minimum_monthly_payment)

# Create DataFrame for the student's debts
student_debt_data = pd.DataFrame({
    'Debt ID': debts,
    'Balance': balances,
    'Interest Rate': interest_rates,
    'Minimum Monthly Payment': minimum_monthly_payments,
    'Loan Tenure (months)': loan_tenures
})

total_available_funds = student_characteristics['Part-time Job Income'] + \
        student_characteristics['Fellowship Amount'] - \
        student_characteristics['Daily Needs Funds'] - \
        student_characteristics['Emergency Funds']

# Display the student's financial profile
print(f"Student's Total Available Funds per month: {total_available_funds}")
print(student_debt_data)
# Out:
# Student's Total Available Funds per month: 1900
#    Debt ID  Balance  Interest Rate  Minimum Monthly Payment  \
# 0        1    18813       0.113928               408.978261
# 1        2    18092       0.157561               311.931034
# 2        3    17018       0.103446               321.094340
# 3        4    14355       0.136969               281.470588
#
#    Loan Tenure (months)
# 0                    46
# 1                    58
# 2                    53
# 3                    51

# %%
from pulp import LpProblem, LpMinimize, LpVariable, lpSum, LpStatus

def optimize_payments(debt_data, available_funds):
    # Create the problem
    prob = LpProblem("Debt_Payment_Strategy", LpMinimize)

    # Calculate the total minimum payments
    total_minimum_payments = debt_data['Minimum Monthly Payment'].sum()

    # Determine the excess funds available for additional payments
    excess_funds = available_funds - total_minimum_payments

    # Define decision variables for the additional payments above the minimum
    extra_payment_vars = [LpVariable(f"Extra_Payment_{i}", lowBound=0) for i in range(len(debt_data))]

    # Define the objective function to maximize the reduction in total interest cost
    prob += -lpSum([extra_payment_vars[i] * debt_data['Interest Rate'].iloc[i] for i in range(len(debt_data))])

    # Add constraints for each debt
    for i in range(len(debt_data)):
        row = debt_data.iloc[i]
        # Ensure additional payments do not exceed the debt balance minus the minimum payment
        prob += extra_payment_vars[i] <= row['Balance'] - row['Minimum Monthly Payment'], f"Extra_payment_limit_debt_{i}"

    # Add a constraint for the total additional funds
    prob += lpSum(extra_payment_vars) <= excess_funds, "Excess_funds_limit"

    # Solve the problem
    prob.solve()

    # Check if the problem is solved successfully
    if prob.status == 1:
        # Return the payment allocation including the minimum payments
        payment_allocation = {f"Debt_{i}": debt_data['Minimum Monthly Payment'].iloc[i] + extra_payment_vars[i].varValue for i in range(len(debt_data))}
        total_interest_saved = sum(extra_payment_vars[i].varValue * debt_data['Interest Rate'].iloc[i] for i in range(len(debt_data)))
        return payment_allocation
    else:
        print("The model did not solve successfully.")
        return None

# Example usage of the function

payment_allocation = optimize_payments(student_debt_data, total_available_funds)
print(payment_allocation)
# Out:
# {'Debt_0': 408.9782608695652, 'Debt_1': 888.4568144827587, 'Debt_2': 321.0943396226415, 'Debt_3': 281.47058823529414}

# %%
from pulp import LpProblem, LpMinimize, LpVariable, lpSum, LpStatus
import pandas as pd

def optimize_payments(debt_data, available_funds):
    # Ensure the required columns exist
    required_columns = ['Balance', 'Minimum Monthly Payment', 'Interest Rate']
    for col in required_columns:
        if col not in debt_data.columns:
            raise KeyError(f"Column '{col}' is missing from the debt_data DataFrame")

    # Create the problem
    prob = LpProblem("Debt_Payment_Strategy", LpMinimize)

    # Define decision variables for the additional payments above the minimum
    extra_payment_vars = [LpVariable(f"Extra_Payment_{i}", lowBound=0) for i in range(len(debt_data))]

    # Define the objective function to minimize the total interest paid
    prob += lpSum([extra_payment_vars[i] * debt_data['Interest Rate'].iloc[i] for i in range(len(debt_data))])

    # Add constraints for each debt
    for i in range(len(debt_data)):
        row = debt_data.iloc[i]
        # Ensure additional payments do not exceed the debt balance
        prob += extra_payment_vars[i] <= row['Balance'], f"Extra_payment_limit_debt_{i}"

    # Add a constraint for the total additional funds
    prob += lpSum(extra_payment_vars) <= available_funds, "Excess_funds_limit"

    # Solve the problem
    prob.solve()

    # Check if the problem is solved successfully
    if prob.status == 1:
        # Return the payment allocation including the minimum payments
        payment_allocation = {f"Payment_{i}": debt_data['Minimum Monthly Payment'].iloc[i] + extra_payment_vars[i].varValue for i in range(len(debt_data))}
        return payment_allocation
    else:
        print("The model did not solve successfully.")
        return None

def simulate_monthly_payments(debt_data, available_funds, months):
    for month in range(1, months + 1):
        print(f"Month {month}")
        payment_allocation = optimize_payments(debt_data, available_funds)
        if payment_allocation is None:
            print("Optimization failed.")
            break

        print(f"Payment Allocation: {payment_allocation}")

        # Update balances based on the payment allocation
        for i in range(len(debt_data)):
            payment = payment_allocation[f"Payment_{i}"]
            debt_data.at[i, 'Balance'] -= payment

        # If all debts are paid off, break the loop
        if debt_data['Balance'].sum() <= 0:
            print("All debts are paid off!")
            break

simulate_monthly_payments(student_debt_data, total_available_funds, 12)
# Out:
# Month 1
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 2
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 3
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 4
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 5
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 6
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 7
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 8
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 9
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 10
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 11
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}
# Month 12
# Payment Allocation: {'Payment_0': 408.9782608695652, 'Payment_1': 311.9310344827586, 'Payment_2': 321.0943396226415, 'Payment_3': 281.47058823529414}

# %%
from pulp import LpProblem, LpVariable, lpSum, LpMaximize

# Assume data is already generated and stored in 'data' DataFrame
grouped_data = data.groupby("Student ID")
# Define dictionaries to store solutions
student_strategies = {}

# Iterate over each student's data and create a strategy
for student_id, student_data in grouped_data:
    # Define PuLP optimization problem
    prob = LpProblem(f"Debt_Payment_Strategy_Student_{student_id}", LpMaximize)

    # Define decision variables
    num_debts = len(student_data)
    payment_vars = [LpVariable(f"Payment_{i}", lowBound=0) for i in range(num_debts)]

    # Define objective function
    prob += lpSum(payment_vars), "Total payments"

    # Define constraints
    total_available_funds = student_data['Part-time Job Income'] + \
        student_data['Fellowship Amount'] - \
        student_data['Daily Needs Funds'] - \
        student_data['Emergency Funds']

    loan_amounts = student_data['Principal Loan Amount']
    interest_rates = student_data['Interest Rate']

    for i in range(num_debts):
        row = student_data.iloc[i]  # Access the row by index
        prob += payment_vars[i] <= row['Balance'], f"Debt_{row['Debt ID']}_payment_limit"
        prob += payment_vars[i] <= total_available_funds.iloc[i], f"Debt_{row['Debt ID']}_funds_limit"
        prob += payment_vars[i] <= 500, f"Debt_{row['Debt ID']}_monthly_installment_limit"

        # Ensure interest_rates and loan_amounts are accessed properly
        prob += payment_vars[i] * ((1 + interest_rates.iloc[i]) ** num_debts) <= loan_amounts.iloc[i] * (1 + interest_rates.iloc[i]), f"Debt_{row['Debt ID']}_total_payment_limit"

    # Solve the problem
    prob.solve()


    # Store the solution in the dictionary
    student_strategies[student_id] = {
        f"Debt_{row[3]}": var.varValue for row, var in zip(student_data.itertuples(), payment_vars) if var.varValue > 0
    }

# Print the strategies for each student
for student_id, strategy in student_strategies.items():
    print(f"Student {student_id} Strategy:")
    if strategy:
        for debt, payment in strategy.items():
            print(f"   {debt}: ${payment:.2f}")
    else:
        print("   No strategy found.")
# Out:
# Student 1 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
#    Debt_3: $500.00
# Student 2 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
# Student 3 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
#    Debt_3: $500.00
# Student 4 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
# Student 5 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
#    Debt_3: $500.00
# Student 6 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
# Student 7 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
#    Debt_3: $500.00
#    Debt_4: $500.00
# Student 8 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
# Student 9 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
#    Debt_3: $500.00
#    Debt_4: $500.00
# Student 10 Strategy:
#    Debt_1: $500.00
#    Debt_2: $500.00
#    Debt_3: $500.00
#    Debt_4: $500.00
